# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(pd.read_csv('/content/train.csv'))
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
x = df.isnull().sum()
drop_col = x[df.isnull().sum()>(35/100*df.shape[0])]
drop_col
# Out:
# Cabin    687
# dtype: int64

# %%
drop_col.index
# Out:
# Index(['Cabin'], dtype='object')

# %%
df.drop(drop_col.index, axis=1, inplace=True)
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df.fillna(df.mean(), inplace=True)
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
df['Embarked'].describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
df['Embarked'].fillna('S', inplace = True)
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass  ...     SibSp     Parch      Fare
# PassengerId     1.000000 -0.005007 -0.035144  ... -0.057527 -0.001652  0.012658
# Survived       -0.005007  1.000000 -0.338481  ... -0.035322  0.081629  0.257307
# Pclass         -0.035144 -0.338481  1.000000  ...  0.083081  0.018443 -0.549500
# Age             0.033207 -0.069809 -0.331339  ... -0.232625 -0.179191  0.091566
# SibSp          -0.057527 -0.035322  0.083081  ...  1.000000  0.414838  0.159651
# Parch          -0.001652  0.081629  0.018443  ...  0.414838  1.000000  0.216225
# Fare            0.012658  0.257307 -0.549500  ...  0.159651  0.216225  1.000000
#
# [7 rows x 7 columns]

# %%
df['FamilySize'] = df['SibSp'] + df['Parch']
df.drop(['SibSp' ,'Parch'], axis=1, inplace=True)
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age      Fare  FamilySize
# PassengerId     1.000000 -0.005007 -0.035144  0.033207  0.012658   -0.040143
# Survived       -0.005007  1.000000 -0.338481 -0.069809  0.257307    0.016639
# Pclass         -0.035144 -0.338481  1.000000 -0.331339 -0.549500    0.065997
# Age             0.033207 -0.069809 -0.331339  1.000000  0.091566   -0.248512
# Fare            0.012658  0.257307 -0.549500  0.091566  1.000000    0.217138
# FamilySize     -0.040143  0.016639  0.065997 -0.248512  0.217138    1.000000

# %%
df['Alone'] = [0 if df['FamilySize'][i]>0 else 1 for i in df.index]
df.head()
# Out:
#    PassengerId  Survived  Pclass  ... Embarked FamilySize  Alone
# 0            1         0       3  ...        S          1      0
# 1            2         1       1  ...        C          1      0
# 2            3         1       3  ...        S          0      1
# 3            4         1       1  ...        S          1      0
# 4            5         0       3  ...        S          0      1
#
# [5 rows x 11 columns]

# %%
df.groupby(['Alone'])['Survived'].mean()
# Out:
# Alone
# 0    0.505650
# 1    0.303538
# Name: Survived, dtype: float64

# %%
df[['Alone','Fare']].corr()
# Out:
#           Alone      Fare
# Alone  1.000000 -0.271832
# Fare  -0.271832  1.000000

# %%
df['Sex'] = [0 if df['Sex'][i]=='male' else 1 for i in df.index] # 1 for female , 0 for male.
df.groupby(['Sex'])['Survived'].mean()
# Out:
# Sex
# 0    0.188908
# 1    0.742038
# Name: Survived, dtype: float64

# %%
df.groupby(['Embarked'])['Survived'].mean()
# Out:
# Embarked
# C    0.553571
# Q    0.389610
# S    0.339009
# Name: Survived, dtype: float64

# %% [markdown]
# CONCLUSION
#
# 1>People with high Class or rich people have higher survival rate than others. 2>The hierarichy might have been followed while saving the passengers. 3>Passengers travelling with their family have higher survival rate. 4>Female Passangers were prioritized over men. 5>Passengers who borded the ship at cherbourg, survived more in proportion than the others.
